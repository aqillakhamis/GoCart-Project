# %% [markdown]
# <a href="https://colab.research.google.com/github/aqillakhamis/GoCart-Project/blob/main/Yolov5_Trolley_detection_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/aqillakhamis/GoCart-Project
# Out:
# Cloning into 'GoCart-Project'...
# remote: Enumerating objects: 418, done.
# remote: Counting objects: 100% (260/260), done.
# remote: Compressing objects: 100% (203/203), done.
# remote: Total 418 (delta 67), reused 217 (delta 56), pack-reused 158
# Receiving objects: 100% (418/418), 16.33 MiB | 42.34 MiB/s, done.
# Resolving deltas: 100% (69/69), done.

# %%
# !python /content/GoCart-Project/src/train.py --img 416 --batch 16 --epochs 300 --data /content/GoCart-Project/src/data.yaml --weights yolov5s.pt --ca
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/GoCart-Project/src/data.yaml, hyp=GoCart-Project/src/data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=GoCart-Project/src/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# requirements: YOLOv5 requirements "ipython" "thop>=0.1.1" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# ...
