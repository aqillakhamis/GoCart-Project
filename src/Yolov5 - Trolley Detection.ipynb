# %% [markdown]
# # Step 1: Mount Google Drive

# %%
from google.colab import drive

drive.mount('/content/MyDrive')
# Out:
# Mounted at /content/MyDrive

# %% [markdown]
# # Step 2: Train Model

# %%
# !python /content/MyDrive/MyDrive/yolov5/train.py --img 416 --batch 16 --epochs 300 --data /content/MyDrive/MyDrive/yolov5/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/MyDrive/MyDrive/yolov5/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-185-ge4398cf Python-3.7.14 torch-1.12.1+cu113 CPU
#
# ...

# %% [markdown]
# # Step 3: Detect the Object

# %%
# !python /content/MyDrive/MyDrive/yolov5/detect.py --weights /content/MyDrive/MyDrive/yolov5/runs/train/exp18/weights/best.pt --img 416 --conf 0.5 --source /content/MyDrive/MyDrive/test/images
# Out:
# detect: weights=['/content/MyDrive/MyDrive/yolov5/runs/train/exp18/weights/best.pt'], source=/content/MyDrive/MyDrive/test/images, data=MyDrive/MyDrive/yolov5/data/coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=MyDrive/MyDrive/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-110-ga4ed988 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/6 /content/MyDrive/MyDrive/test/images/test.jpg: 416x416 1 Trolley, 8.4ms
# image 2/6 /content/MyDrive/MyDrive/test/images/test2.jpg: 416x416 1 Trolley, 8.1ms
# ...
